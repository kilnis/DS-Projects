# %% [markdown]
# <a href="https://colab.research.google.com/github/kilnis/DS-Projects/blob/main/Task_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Домашняя работа 3. Модуль 2**

# %% [markdown]
# Таблицы были взяты с сайта https://archive.ics.uci.edu/dataset/186/wine+quality

# %%
import pandas as pd
import numpy as np

# %%
# !unzip wine+quality.zip
# Out:
# Archive:  wine+quality.zip
#   inflating: winequality-red.csv
#   inflating: winequality-white.csv
#   inflating: winequality.names

# %%
red = pd.read_csv('winequality-red.csv', sep = ';')
red.sample(5)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 770             7.1              0.59         0.02             2.3      0.082
# 1261            6.3              1.02         0.00             2.0      0.083
# 1020           11.3              0.36         0.66             2.4      0.123
# 785             9.9              0.35         0.41             2.3      0.083
# 773             7.9              0.40         0.29             1.8      0.157
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 770                  24.0                  94.0  0.99744  3.55       0.53
# 1261                 17.0                  24.0  0.99437  3.59       0.55
# 1020                  3.0                   8.0  0.99642  3.20       0.53
# 785                  11.0                  61.0  0.99820  3.21       0.50
# 773                   1.0                  44.0  0.99730  3.30       0.92
#
#       alcohol  quality
# 770       9.7        6
# ...

# %%
white = pd.read_csv('winequality-white.csv', sep = ';')
white.sample(5)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 3930            6.1              0.28         0.26            1.50      0.030
# 4625            8.3              0.49         0.23            6.65      0.034
# 2491            6.0              0.20         0.24            5.30      0.075
# 2209            7.0              0.32         0.35            1.50      0.039
# 3528            6.9              0.75         0.13            6.30      0.036
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 3930                 25.0                 101.0  0.98894  3.03       0.41
# 4625                  6.0                 158.0  0.99344  3.05       0.48
# 2491                 49.0                 201.0  0.99466  3.21       0.43
# 2209                 24.0                 125.0  0.99180  3.17       0.64
# 3528                 19.0                  50.0  0.99312  3.09       0.25
#
#       alcohol  quality
# 3930     12.1        6
# ...

# %% [markdown]
# # Начнем с анализа вещественных признаков.

# %%
red.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...
